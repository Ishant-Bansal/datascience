# %%
import pandas as pd

# %%
data = pd.read_csv("laptopPrice.csv")

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [823 rows x 19 columns]

# %%
df.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [823 rows x 19 columns]>

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull()
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0    False            False           False            False   False
# 1    False            False           False            False   False
# 2    False            False           False            False   False
# 3    False            False           False            False   False
# 4    False            False           False            False   False
# ..     ...              ...             ...              ...     ...
# 818  False            False           False            False   False
# 819  False            False           False            False   False
# 820  False            False           False            False   False
# 821  False            False           False            False   False
# 822  False            False           False            False   False
#
#      ram_type    ssd    hdd     os  os_bit  graphic_card_gb  weight  warranty  \
# 0       False  False  False  False   False            False   False     False
# 1       False  False  False  False   False            False   False     False
# 2       False  False  False  False   False            False   False     False
# 3       False  False  False  False   False            False   False     False
# 4       False  False  False  False   False            False   False     False
# ..        ...    ...    ...    ...     ...              ...     ...       ...
# 818     False  False  False  False   False            False   False     False
# 819     False  False  False  False   False            False   False     False
# 820     False  False  False  False   False            False   False     False
# 821     False  False  False  False   False            False   False     False
# 822     False  False  False  False   False            False   False     False
#
#      Touchscreen  msoffice  Price  rating  Number of Ratings  \
# 0          False     False  False   False              False
# 1          False     False  False   False              False
# 2          False     False  False   False              False
# 3          False     False  False   False              False
# 4          False     False  False   False              False
# ..           ...       ...    ...     ...                ...
# 818        False     False  False   False              False
# 819        False     False  False   False              False
# 820        False     False  False   False              False
# 821        False     False  False   False              False
# 822        False     False  False   False              False
#
#      Number of Reviews
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ..                 ...
# 818              False
# 819              False
# 820              False
# 821              False
# 822              False
#
# [802 rows x 19 columns]

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.notna()
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0     True             True            True             True    True
# 1     True             True            True             True    True
# 2     True             True            True             True    True
# 3     True             True            True             True    True
# 4     True             True            True             True    True
# ..     ...              ...             ...              ...     ...
# 818   True             True            True             True    True
# 819   True             True            True             True    True
# 820   True             True            True             True    True
# 821   True             True            True             True    True
# 822   True             True            True             True    True
#
#      ram_type   ssd   hdd    os  os_bit  graphic_card_gb  weight  warranty  \
# 0        True  True  True  True    True             True    True      True
# 1        True  True  True  True    True             True    True      True
# 2        True  True  True  True    True             True    True      True
# 3        True  True  True  True    True             True    True      True
# 4        True  True  True  True    True             True    True      True
# ..        ...   ...   ...   ...     ...              ...     ...       ...
# 818      True  True  True  True    True             True    True      True
# 819      True  True  True  True    True             True    True      True
# 820      True  True  True  True    True             True    True      True
# 821      True  True  True  True    True             True    True      True
# 822      True  True  True  True    True             True    True      True
#
#      Touchscreen  msoffice  Price  rating  Number of Ratings  \
# 0           True      True   True    True               True
# 1           True      True   True    True               True
# 2           True      True   True    True               True
# 3           True      True   True    True               True
# 4           True      True   True    True               True
# ..           ...       ...    ...     ...                ...
# 818         True      True   True    True               True
# 819         True      True   True    True               True
# 820         True      True   True    True               True
# 821         True      True   True    True               True
# 822         True      True   True    True               True
#
#      Number of Reviews
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True
# ..                 ...
# 818               True
# 819               True
# 820               True
# 821               True
# 822               True
#
# [802 rows x 19 columns]

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [802 rows x 19 columns]

# %%
df.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df.drop(['weight','Number of Ratings','Number of Reviews'],axis=1,inplace=True)

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# No     706
# Yes     96
# Name: count, dtype: int64

# %%
df['msoffice'].value_counts()
# Out:
# msoffice
# No     522
# Yes    280
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# brand              object
# processor_brand    object
# processor_name     object
# processor_gnrtn    object
# ram_gb             object
# ram_type           object
# ssd                object
# hdd                object
# os                 object
# os_bit             object
# graphic_card_gb    object
# warranty           object
# Touchscreen        object
# msoffice           object
# Price               int64
# rating             object
# dtype: object

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
brand_dict = {'ASUS': 1, 'Lenovo' : 2, 'acer': 3, 'Avita': 4, 'HP': 5, 'DELL':6 , 'MSI':7, 'APPLE':8}
df['brand'] = df['brand'].map(brand_dict)

# %%
df['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
processor_brand_dict = {'Intel' : 1, 'AMD':2, 'M1': 3}
df['processor_brand'] = df['processor_brand'].map(processor_brand_dict)

# %%
df['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
processor_name_dict = {'Core i3' : 1, 'Core i5':2, 'Celeron Dual':3, 'Ryzen 5':4, 'Core i7':5,
       'Core i9':6, 'M1':7, 'Pentium Quad':8, 'Ryzen 3':9, 'Ryzen 7':10, 'Ryzen 9':11}
df['processor_name'] = df['processor_name'].map(processor_name_dict)

# %%
df['processor_gnrtn'].unique()
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
processor_gnrth_dict = {'10th':5, 'Not Available':0, '11th':6, '7th':2, '8th':3, '9th':4, '4th':1,
       '12th':7}
df['processor_gnrtn'] = df['processor_gnrtn'].map(processor_gnrth_dict)

# %%
df.dtypes
# Out:
# brand               int64
# processor_brand     int64
# processor_name      int64
# processor_gnrtn     int64
# ram_gb             object
# ram_type           object
# ssd                object
# hdd                object
# os                 object
# os_bit             object
# graphic_card_gb    object
# warranty           object
# Touchscreen        object
# msoffice           object
# Price               int64
# rating             object
# dtype: object

# %%
df['ram_gb'].unique()
# Out:
# array(['4 GB', '8 GB', '16 GB', '32 GB'], dtype=object)

# %%
ram_gb_dict = {'4 GB':4, '8 GB':8, '16 GB':16, '32 GB':32}
df['ram_gb'] = df['ram_gb'].map(ram_gb_dict)

# %%
df['ram_type'].unique()
# Out:
# array(['DDR4', 'LPDDR4', 'LPDDR4X', 'DDR5', 'DDR3', 'LPDDR3'],
#       dtype=object)

# %%
ram_type_dict = {'DDR4':3, 'LPDDR4':4, 'LPDDR4X':5, 'DDR5':6, 'DDR3':1, 'LPDDR3':2}
df['ram_type'] = df['ram_type'].map(ram_type_dict)

# %%
df['ssd'].unique()
# Out:
# array(['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB',
#        '3072 GB'], dtype=object)

# %%
ssd_dict = {'0 GB':0, '512 GB':512, '256 GB':256, '128 GB':128, '1024 GB':1024, '2048 GB':2048,
       '3072 GB':3072}
df['ssd'] = df['ssd'].map(ssd_dict)

# %%
df['hdd'].unique()
# Out:
# array(['1024 GB', '0 GB', '512 GB', '2048 GB'], dtype=object)

# %%
hdd_dict = {'1024 GB':1024, '0 GB':0, '512 GB':512, '2048 GB':2048}
df['hdd'] = df['hdd'].map(hdd_dict)

# %%
df['os'].unique()
# Out:
# array(['Windows', 'DOS', 'Mac'], dtype=object)

# %%
os_dict = {'Windows':1, 'DOS':2, 'Mac':3}
df['os'] = df['os'].map(os_dict)

# %%
df['os_bit'].unique()
# Out:
# array(['64-bit', '32-bit'], dtype=object)

# %%
os_bit_dict = {'64-bit':64, '32-bit':32}
df['os_bit'] = df['os_bit'].map(os_bit_dict)

# %%
df['graphic_card_gb'].unique()
# Out:
# array(['0 GB', '2 GB', '4 GB', '6 GB', '8 GB'], dtype=object)

# %%
graphic_card_gb_dict = {'0 GB':0, '2 GB':2, '4 GB':4, '6 GB':6, '8 GB':8}
df['graphic_card_gb'] = df['graphic_card_gb'].map(graphic_card_gb_dict)

# %%
df['warranty'].unique()
# Out:
# array(['No warranty', '1 year', '2 years', '3 years'], dtype=object)

# %%
warranty_dict = {'No warranty':0, '1 year':1, '2 years':3, '3 years':4}
df['warranty'] = df['warranty'].map(warranty_dict)

# %%
df['Touchscreen'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
touchscreen_dict = {'No':0, 'Yes':1}
df['Touchscreen'] = df['Touchscreen'].map(touchscreen_dict)

# %%
df['msoffice'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
msoffice_dict = {'No':0, 'Yes':1}
df['msoffice'] = df['msoffice'].map(msoffice_dict)

# %%
df['rating'].unique()
# Out:
# array(['2 stars', '3 stars', '4 stars', '5 stars', '1 star'], dtype=object)

# %%
rating_dict = {'2 stars':2, '3 stars':3, '4 stars':4, '5 stars':5, '1 star':1}
df['rating'] = df['rating'].map(rating_dict)

# %%
df.dtypes
# Out:
# brand              int64
# processor_brand    int64
# processor_name     int64
# processor_gnrtn    int64
# ram_gb             int64
# ram_type           int64
# ssd                int64
# hdd                int64
# os                 int64
# os_bit             int64
# graphic_card_gb    int64
# warranty           int64
# Touchscreen        int64
# msoffice           int64
# Price              int64
# rating             int64
# dtype: object

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                5       4
# 1        2                1               1                5       4
# 2        2                1               1                5       4
# 3        1                1               2                5       8
# 4        1                1               3                0       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                0       4
# 819      1                2              11                0       4
# 820      1                2              11                0       4
# 821      1                2              11                0       4
# 822      2                2               4                5       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  warranty  Touchscreen  \
# 0           3     0  1024   1      64                0         0            0
# 1           3     0  1024   1      64                0         0            0
# 2           3     0  1024   1      64                0         0            0
# 3           3   512     0   1      32                2         0            0
# 4           3     0   512   1      64                0         0            0
# ..        ...   ...   ...  ..     ...              ...       ...          ...
# 818         3  1024     0   1      64                0         1            0
# 819         3  1024     0   1      64                0         1            0
# 820         3  1024     0   1      64                4         1            0
# 821         3  1024     0   1      64                4         1            0
# 822         3   512     0   2      64                0         0            0
#
#      msoffice   Price  rating
# 0           0   34649       2
# 1           0   38999       3
# 2           0   39999       3
# 3           0   69990       3
# 4           0   26990       3
# ..        ...     ...     ...
# 818         0  135990       3
# 819         0  144990       3
# 820         0  149990       3
# 821         0  142990       3
# 822         0   57490       4
#
# [802 rows x 16 columns]

# %%
x = df.drop('Price',axis=1)
y=df['Price']

# %%
x
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                5       4
# 1        2                1               1                5       4
# 2        2                1               1                5       4
# 3        1                1               2                5       8
# 4        1                1               3                0       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                0       4
# 819      1                2              11                0       4
# 820      1                2              11                0       4
# 821      1                2              11                0       4
# 822      2                2               4                5       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  warranty  Touchscreen  \
# 0           3     0  1024   1      64                0         0            0
# 1           3     0  1024   1      64                0         0            0
# 2           3     0  1024   1      64                0         0            0
# 3           3   512     0   1      32                2         0            0
# 4           3     0   512   1      64                0         0            0
# ..        ...   ...   ...  ..     ...              ...       ...          ...
# 818         3  1024     0   1      64                0         1            0
# 819         3  1024     0   1      64                0         1            0
# 820         3  1024     0   1      64                4         1            0
# 821         3  1024     0   1      64                4         1            0
# 822         3   512     0   2      64                0         0            0
#
#      msoffice  rating
# 0           0       2
# 1           0       3
# 2           0       3
# 3           0       3
# 4           0       3
# ..        ...     ...
# 818         0       3
# 819         0       3
# 820         0       3
# 821         0       3
# 822         0       4
#
# [802 rows x 15 columns]

# %%
y
# Out:
# 0       34649
# 1       38999
# 2       39999
# 3       69990
# 4       26990
#         ...
# 818    135990
# 819    144990
# 820    149990
# 821    142990
# 822     57490
# Name: Price, Length: 802, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.2)

# %%
x_train
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 442      1                1               2                6       8
# 598      1                1               5                5      16
# 452      1                1               2                6       8
# 696      6                2               4                0       8
# 339      1                1               2                6       8
# ..     ...              ...             ...              ...     ...
# 73       2                1               1                5       4
# 108      6                1               1                6       8
# 275      2                1               2                5       8
# 445      1                1               2                6       8
# 104      1                1               1                6       8
#
#      ram_type  ssd   hdd  os  os_bit  graphic_card_gb  warranty  Touchscreen  \
# 442         3  256  1024   1      32                0         1            0
# 598         5    0   512   2      32                6         0            0
# 452         3  256  1024   1      64                2         1            0
# 696         3  512     0   1      64                0         1            0
# 339         5  512     0   1      64                0         1            1
# ..        ...  ...   ...  ..     ...              ...       ...          ...
# 73          3  256     0   1      32                0         0            0
# 108         3  512     0   1      64                0         1            1
# 275         3  512     0   1      64                2         1            0
# 445         3  256  1024   1      64                0         1            0
# 104         3  512     0   1      64                0         1            0
#
#      msoffice  rating
# 442         1       4
# 598         0       3
# 452         1       4
# 696         1       3
# 339         0       4
# ..        ...     ...
# 73          0       3
# 108         0       4
# 275         1       3
# 445         0       3
# 104         1       4
#
# [641 rows x 15 columns]

# %%
x_test
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 196      3                1               2                0       8
# 299      1                1               2                6       8
# 171      6                1               1                5       8
# 537      5                1               5                5      16
# 551      7                1               5                6      16
# ..     ...              ...             ...              ...     ...
# 368      1                1               2                6       8
# 361      5                1               2                5       8
# 446      6                1               2                6       8
# 767      2                2              10                0       4
# 529      2                1               5                6      16
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  warranty  Touchscreen  \
# 196         6     0   512   1      32                4         0            0
# 299         5   512     0   1      32                0         1            0
# 171         3   256  1024   1      64                0         1            0
# 537         3  1024     0   1      64                6         1            0
# 551         3  1024     0   1      64                8         3            0
# ..        ...   ...   ...  ..     ...              ...       ...          ...
# 368         5   512     0   1      64                0         1            1
# 361         3   512     0   1      64                0         1            1
# 446         3   256  1024   1      64                0         1            0
# 767         3   512     0   1      64                4         1            0
# 529         3   512     0   1      32                0         0            0
#
#      msoffice  rating
# 196         0       4
# 299         1       4
# 171         1       5
# 537         1       4
# 551         0       4
# ..        ...     ...
# 368         0       3
# 361         0       5
# 446         0       4
# 767         0       3
# 529         0       3
#
# [161 rows x 15 columns]

# %%
y_train
# Out:
# 442     50990
# 598    146490
# 452     60190
# 696     59490
# 339     99990
#         ...
# 73      41990
# 108     60790
# 275     57500
# 445     52990
# 104     44990
# Name: Price, Length: 641, dtype: int64

# %%
y_test
# Out:
# 196     50990
# 299     72990
# 171     41490
# 537    144690
# 551    129990
#         ...
# 368    114990
# 361    126000
# 446     57990
# 767    106990
# 529    110999
# Name: Price, Length: 161, dtype: int64

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((641, 15), (641,), (161, 15), (161,))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.7088710255365696

# %%
lr.score(x_test,y_test)
# Out:
# 0.6287570101342805

# %%
pred = lr.predict(x_test)

# %%
pred
# Out:
# array([ 61469.66297559,  67779.95028334,  48176.74833924, 149477.26110645,
#        163631.80218008, 141006.59520969, 138065.62335793,  63525.38143546,
#         59134.93575333,  99214.69827442,  41823.98071873,  33598.31633975,
#         81377.17154278, 104960.37089159,  55892.92016247, 113240.00020098,
#         77801.39431895,  59301.84990315,  67110.47624237, 166303.8715768 ,
#         35091.79327692,  35449.70320688,  74563.86883706,  52868.30696629,
#         28982.14565725,  44080.93811923,  76804.74817988, 164065.56006369,
#         47097.73601986,  34890.42816458,  57416.62234333,  57013.9034226 ,
#         56308.30084086,  65191.14966777,  57967.73202925,  28550.61066753,
#        177921.47204296,  80196.83183243,  52038.4429206 ,  67154.77261149,
#         27653.28413848,  72579.60245833,  51227.00041262,  40726.90171725,
#        130101.73725849,  49433.3986945 , 144999.88132817,  63663.98532439,
#        117557.92339396, 109137.61590713,  85683.68532784, 128824.9452973 ,
#        109005.82858001,  67359.39642116,  68252.32330001, 151179.68735435,
#        116024.43806552,  56237.79729982,  79371.04464788, 146748.30285391,
#         83216.11602947,  43308.16072822,  49676.88690526,  76472.53280019,
