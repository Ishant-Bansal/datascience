# %%
import pandas as pd

# %%
data = pd.read_csv('survey-lung-cancer.csv')
df = pd.DataFrame(data)

# %%
df
# Out:
#     GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC DISEASE  \
# 0        M   69      NO            YES     YES            NO              NO
# 1        M   74     YES             NO      NO            NO             YES
# 2        F   59      NO             NO      NO           YES              NO
# 3        M   63     YES            YES     YES            NO              NO
# 4        F   63      NO            YES      NO            NO              NO
# ..     ...  ...     ...            ...     ...           ...             ...
# 304      F   56      NO             NO      NO           YES             YES
# 305      M   70     YES             NO      NO            NO              NO
# 306      M   58     YES             NO      NO            NO              NO
# 307      M   67     YES             NO     YES            NO              NO
# 308      M   62      NO             NO      NO           YES              NO
#
# ...

# %%
df.dtypes
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                  object
# YELLOW_FINGERS           object
# ANXIETY                  object
# PEER_PRESSURE            object
# CHRONIC DISEASE          object
# FATIGUE                  object
# ALLERGY                  object
# WHEEZING                 object
# ALCOHOL CONSUMING        object
# COUGHING                 object
# SHORTNESS OF BREATH      object
# SWALLOWING DIFFICULTY    object
# CHEST PAIN               object
# LUNG_CANCER              object
# dtype: object

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 304     True
# 305     True
# 306     True
# 307     True
# 308     True
# Length: 309, dtype: bool

# %%
df.drop_duplicates()
# Out:
#     GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC DISEASE  \
# 0        M   69      NO            YES     YES            NO              NO
# 1        M   74     YES             NO      NO            NO             YES
# 2        F   59      NO             NO      NO           YES              NO
# 3        M   63     YES            YES     YES            NO              NO
# 4        F   63      NO            YES      NO            NO              NO
# ..     ...  ...     ...            ...     ...           ...             ...
# 279      F   59      NO            YES     YES           YES              NO
# 280      F   59     YES             NO      NO            NO             YES
# 281      M   55     YES             NO      NO            NO              NO
# 282      M   46      NO            YES     YES            NO              NO
# 283      M   60      NO            YES     YES            NO              NO
#
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 304     True
# 305     True
# 306     True
# 307     True
# 308     True
# Length: 309, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                  object
# YELLOW_FINGERS           object
# ANXIETY                  object
# PEER_PRESSURE            object
# CHRONIC DISEASE          object
# FATIGUE                  object
# ALLERGY                  object
# WHEEZING                 object
# ALCOHOL CONSUMING        object
# COUGHING                 object
# SHORTNESS OF BREATH      object
# SWALLOWING DIFFICULTY    object
# CHEST PAIN               object
# LUNG_CANCER              object
# dtype: object

# %%
df['GENDER'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
gender_dict = {'M':1, 'F':2}
df['GENDER']= df['GENDER'].map(gender_dict)

# %%
df['ALCOHOL CONSUMING'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
alcohol_consuming_dict = {'YES' : 1, 'NO' : 0}
df['ALCOHOL CONSUMING'] = df['ALCOHOL CONSUMING'].map(alcohol_consuming_dict)

# %%
df['ALLERGY '].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
allergy_dict = {'NO' : 0, 'YES' : 1}
df['ALLERGY '] = df['ALLERGY '].map(allergy_dict)

# %%
df['ANXIETY'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
anxiety_dict = {'NO' : 0, 'YES' : 1}
df['ANXIETY'] = df['ANXIETY'].map(anxiety_dict)

# %%
df['SMOKING'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
smoking_dict = {'NO' : 0, 'YES' : 1}
df['SMOKING'] = df['SMOKING'].map(smoking_dict)

# %%
df['YELLOW_FINGERS'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
yellow_finger_dict = {'NO' : 0, 'YES' : 1}
df['YELLOW_FINGERS'] = df['YELLOW_FINGERS'].map(yellow_finger_dict)

# %%
df['PEER_PRESSURE'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
peer_pressure_dict = {'NO' : 0, 'YES' : 1}
df['PEER_PRESSURE'] = df['PEER_PRESSURE'].map(peer_pressure_dict)

# %%
df['CHRONIC DISEASE'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
chronic_disease_dict = {'NO' : 0, 'YES' : 1}
df['CHRONIC DISEASE'] = df['CHRONIC DISEASE'].map(chronic_disease_dict)

# %%
df['FATIGUE '].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
fatigue_dict = {'NO' : 0, 'YES' : 1}
df['FATIGUE '] = df['FATIGUE '].map(fatigue_dict)

# %%
df['WHEEZING'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
wheezing_dict = {'NO' : 0, 'YES' : 1}
df['WHEEZING'] = df['WHEEZING'].map(wheezing_dict)

# %%
df['COUGHING'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
coughing_dict = {'NO' : 0, 'YES' : 1}
df['COUGHING'] = df['COUGHING'].map(coughing_dict)

# %%
df['SHORTNESS OF BREATH'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
sob_dict = {'NO' : 0, 'YES' : 1}
df['SHORTNESS OF BREATH'] = df['SHORTNESS OF BREATH'].map(sob_dict)

# %%
df['SWALLOWING DIFFICULTY'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
sd_dict = {'NO' : 0, 'YES' : 1}
df['SWALLOWING DIFFICULTY'] = df['SWALLOWING DIFFICULTY'].map(sd_dict)

# %%
df['CHEST PAIN'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
cp_dict = {'NO' : 0, 'YES' : 1}
df['CHEST PAIN'] = df['CHEST PAIN'].map(cp_dict)

# %%
df['LUNG_CANCER'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
lc_dict = {'NO' : 0, 'YES' : 1}
df['LUNG_CANCER'] = df['LUNG_CANCER'].map(lc_dict)

# %%
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        0               1        1              0
# 1         1   74        1               0        0              0
# 2         2   59        0               0        0              1
# 3         1   63        1               1        1              0
# 4         2   63        0               1        0              0
# ..      ...  ...      ...             ...      ...            ...
# 279       2   59        0               1        1              1
# 280       2   59        1               0        0              0
# 281       1   55        1               0        0              0
# 282       1   46        0               1        1              0
# 283       1   60        0               1        1              0
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  0         1         0         1                  1
# ...

# %%
df.to_csv('clean_survey-lung-cancer.csv')

# %%
x=df.drop('LUNG_CANCER',axis=1)
y=df['LUNG_CANCER']

# %%
x
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        0               1        1              0
# 1         1   74        1               0        0              0
# 2         2   59        0               0        0              1
# 3         1   63        1               1        1              0
# 4         2   63        0               1        0              0
# ..      ...  ...      ...             ...      ...            ...
# 279       2   59        0               1        1              1
# 280       2   59        1               0        0              0
# 281       1   55        1               0        0              0
# 282       1   46        0               1        1              0
# 283       1   60        0               1        1              0
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  0         1         0         1                  1
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 279    1
# 280    0
# 281    0
# 282    0
# 283    1
# Name: LUNG_CANCER, Length: 276, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.2)

# %%
x_train,y_train,x_test,y_test
# Out:
# (     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
#  265       2   60        1               1        1              1
#  238       2   38        0               1        0              0
#  33        2   67        1               1        1              0
#  160       2   55        0               0        0              1
#  151       1   62        0               0        0              1
#  ..      ...  ...      ...             ...      ...            ...
#  191       2   55        1               1        1              1
#  71        2   66        1               1        1              1
#  108       2   49        0               0        0              1
#  278       2   77        1               1        1              1
#  104       2   72        1               1        1              1
#
#       CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
#  265                0         1         1         0                  0
# ...

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((220, 15), (220,), (56, 15), (56,))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.36480540852056953

# %%
lr.score(x_test,y_test)
# Out:
# 0.442851068533897
