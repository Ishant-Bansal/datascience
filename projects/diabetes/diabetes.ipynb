# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('diabetes.csv')

# %%
df = pd.DataFrame(data)

# %%
df.head(2)
# Out:
#    age  gender   bmi  blood_pressure  glucose_level  physical_activity  \
# 0   39    Male  27.6             100            191                9.5
# 1   31  Female  26.5             136            131                3.1
#
#   smoking_status family_history alcohol_intake region diabetes
# 0        Current             No       Moderate   West       No
# 1         Former             No           High  South       No

# %%
df.dtypes
# Out:
# age                    int64
# gender                object
# bmi                  float64
# blood_pressure         int64
# glucose_level          int64
# physical_activity    float64
# smoking_status        object
# family_history        object
# alcohol_intake        object
# region                object
# diabetes              object
# dtype: object

# %%
df.drop(['region'],axis=1,inplace=True)

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['gender'] = df['gender'].map({'Male': 0, 'Female': 1})

# %%
df.dtypes
# Out:
# age                    int64
# gender                 int64
# bmi                  float64
# blood_pressure         int64
# glucose_level          int64
# physical_activity    float64
# smoking_status        object
# family_history        object
# alcohol_intake        object
# diabetes              object
# dtype: object

# %%
df['smoking_status'].unique()
# Out:
# array(['Current', 'Former', 'Never'], dtype=object)

# %%
df['smoking_status'] = df['smoking_status'].map({'Current':2, 'Former':1, 'Never':0})

# %%
df.dtypes
# Out:
# age                    int64
# gender                 int64
# bmi                  float64
# blood_pressure         int64
# glucose_level          int64
# physical_activity    float64
# smoking_status         int64
# family_history        object
# alcohol_intake        object
# diabetes              object
# dtype: object

# %%
df.isnull().sum()
# Out:
# age                    0
# gender                 0
# bmi                    0
# blood_pressure         0
# glucose_level          0
# physical_activity      0
# smoking_status         0
# family_history         0
# alcohol_intake       357
# diabetes               0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['family_history'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['family_history'] = df['family_history'].map({'Yes': 1, 'No': 0})

# %%
df.dtypes
# Out:
# age                    int64
# gender                 int64
# bmi                  float64
# blood_pressure         int64
# glucose_level          int64
# physical_activity    float64
# smoking_status         int64
# family_history         int64
# alcohol_intake        object
# diabetes              object
# dtype: object

# %%
df['alcohol_intake'].unique()
# Out:
# array(['Moderate', 'High'], dtype=object)

# %%
df['alcohol_intake'] = df['alcohol_intake'].map({'Moderate': 0, 'High': 1,})

# %%
df.dtypes
# Out:
# age                    int64
# gender                 int64
# bmi                  float64
# blood_pressure         int64
# glucose_level          int64
# physical_activity    float64
# smoking_status         int64
# family_history         int64
# alcohol_intake         int64
# diabetes              object
# dtype: object

# %%
df
# Out:
#      age  gender   bmi  blood_pressure  glucose_level  physical_activity  \
# 0     39       0  27.6             100            191                9.5
# 1     31       1  26.5             136            131                3.1
# 2     26       0  28.1             175            193                0.3
# 3     60       1  30.0             140            163                1.4
# 6     41       1  22.0             169            121                5.1
# ..   ...     ...   ...             ...            ...                ...
# 991   31       1  18.5              91            123                2.3
# 992   69       0  37.6             161             75                2.6
# 994   41       1  28.2             100            148                2.4
# 997   70       0  34.3             172            183                7.9
# 998   22       0  24.3             149            141                6.0
#
#      smoking_status  family_history  alcohol_intake diabetes
# 0                 2               0               0       No
# 1                 1               0               1       No
# 2                 1               1               1       No
# 3                 0               0               0       No
# 6                 2               1               1      Yes
# ..              ...             ...             ...      ...
# 991               0               0               1      Yes
# 992               0               1               1       No
# 994               2               0               0       No
# 997               1               1               0       No
# 998               0               1               0       No
#
# [643 rows x 10 columns]

# %%
df['diabetes'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['diabetes'] = df['diabetes'].map({'Yes': 1, 'No': 0})

# %%
df.dtypes
# Out:
# age                    int64
# gender                 int64
# bmi                  float64
# blood_pressure         int64
# glucose_level          int64
# physical_activity    float64
# smoking_status         int64
# family_history         int64
# alcohol_intake         int64
# diabetes               int64
# dtype: object

# %%
x = df.drop(['diabetes'], axis=1)
y = df['diabetes']

# %%
x
# Out:
#      age  gender   bmi  blood_pressure  glucose_level  physical_activity  \
# 0     39       0  27.6             100            191                9.5
# 1     31       1  26.5             136            131                3.1
# 2     26       0  28.1             175            193                0.3
# 3     60       1  30.0             140            163                1.4
# 6     41       1  22.0             169            121                5.1
# ..   ...     ...   ...             ...            ...                ...
# 991   31       1  18.5              91            123                2.3
# 992   69       0  37.6             161             75                2.6
# 994   41       1  28.2             100            148                2.4
# 997   70       0  34.3             172            183                7.9
# 998   22       0  24.3             149            141                6.0
#
#      smoking_status  family_history  alcohol_intake
# 0                 2               0               0
# 1                 1               0               1
# 2                 1               1               1
# 3                 0               0               0
# 6                 2               1               1
# ..              ...             ...             ...
# 991               0               0               1
# 992               0               1               1
# 994               2               0               0
# 997               1               1               0
# 998               0               1               0
#
# [643 rows x 9 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 6      1
#       ..
# 991    1
# 992    0
# 994    0
# 997    0
# 998    0
# Name: diabetes, Length: 643, dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=100, random_state=42)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2, random_state=42)
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rfr.score(x_test, y_test)
# Out:
# -0.08022840909090911

# %%
rfr.predict(x_test)
# Out:
# array([0.29, 0.37, 0.22, 0.28, 0.23, 0.21, 0.18, 0.16, 0.26, 0.38, 0.18,
#        0.31, 0.6 , 0.24, 0.33, 0.2 , 0.23, 0.36, 0.29, 0.21, 0.39, 0.41,
#        0.33, 0.47, 0.35, 0.42, 0.1 , 0.29, 0.5 , 0.19, 0.32, 0.26, 0.14,
#        0.23, 0.18, 0.3 , 0.14, 0.61, 0.23, 0.59, 0.24, 0.21, 0.47, 0.35,
#        0.21, 0.37, 0.25, 0.28, 0.27, 0.1 , 0.2 , 0.26, 0.73, 0.56, 0.3 ,
#        0.27, 0.55, 0.24, 0.44, 0.05, 0.82, 0.22, 0.16, 0.48, 0.13, 0.53,
#        0.28, 0.27, 0.35, 0.27, 0.22, 0.21, 0.4 , 0.52, 0.43, 0.33, 0.3 ,
#        0.2 , 0.39, 0.12, 0.24, 0.25, 0.45, 0.29, 0.31, 0.26, 0.42, 0.16,
#        0.11, 0.26, 0.15, 0.19, 0.32, 0.19, 0.45, 0.51, 0.16, 0.37, 0.36,
#        0.2 , 0.36, 0.25, 0.35, 0.32, 0.39, 0.33, 0.25, 0.33, 0.32, 0.17,
#        0.27, 0.14, 0.39, 0.49, 0.25, 0.35, 0.3 , 0.24, 0.41, 0.2 , 0.29,
#        0.18, 0.31, 0.5 , 0.2 , 0.2 , 0.37, 0.15, 0.19])

# %%
y_test
# Out:
# 978    0
# 565    0
# 751    0
# 438    0
# 108    1
#       ..
# 529    1
# 997    0
# 324    0
# 946    1
# 201    0
# Name: diabetes, Length: 129, dtype: int64

# %%
df.to_csv('diabetes_cleaned.csv', index=False)
